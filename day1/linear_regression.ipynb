# %% [markdown]
# ## 1.1 An example of linear regression with Python using the machine learning module 'sklearn'

# %%
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate sample data

# %%
#creating sample data: predictor (X) and outcome (Y)
m = 30
theta0_true = 2
theta1_true = 0.5
X = np.linspace(-1,1,m) #interpollation

rand_noise_mu = 0
rand_noise_std = 0.1

rand_noise = np.random.normal(rand_noise_mu, rand_noise_std, m)
Y = theta0_true + theta1_true * X + rand_noise

# %% [markdown]
# ### Visualize the generated data X, Y

# %%
#print and plot the data
print('X',X)
print('Y',Y)

plt.scatter(X, Y)

# %% [markdown]
# ### Using sklearn for linear regression

# %%
from sklearn import linear_model #we import the model for the linear regression

# %% [markdown]
# To be able to work with linear_model, we need to restucture X to a table format with a row (or, array) per sample. Because we are performing a univariate regression, there is only one column.

# %%
print("X before reshaping")
print(X)

print("\n\nX after reshaping")
X = np.reshape(X, (-1, 1)) #
print(X)
# Out:
# X before reshaping
# [-1.         -0.93103448 -0.86206897 -0.79310345 -0.72413793 -0.65517241
#  -0.5862069  -0.51724138 -0.44827586 -0.37931034 -0.31034483 -0.24137931
#  -0.17241379 -0.10344828 -0.03448276  0.03448276  0.10344828  0.17241379
#   0.24137931  0.31034483  0.37931034  0.44827586  0.51724138  0.5862069
#   0.65517241  0.72413793  0.79310345  0.86206897  0.93103448  1.        ]
#
#
# X after reshaping
# [[-1.        ]
#  [-0.93103448]
#  [-0.86206897]
#  [-0.79310345]
#  [-0.72413793]
#  [-0.65517241]
#  [-0.5862069 ]
#  [-0.51724138]
#  [-0.44827586]
#  [-0.37931034]
#  [-0.31034483]
#  [-0.24137931]
#  [-0.17241379]
#  [-0.10344828]
#  [-0.03448276]
#  [ 0.03448276]
#  [ 0.10344828]
#  [ 0.17241379]
#  [ 0.24137931]
#  [ 0.31034483]
#  [ 0.37931034]
#  [ 0.44827586]
#  [ 0.51724138]
#  [ 0.5862069 ]
#  [ 0.65517241]
#  [ 0.72413793]
#  [ 0.79310345]
#  [ 0.86206897]
#  [ 0.93103448]
#  [ 1.        ]]

# %% [markdown]
# Now we can perform the regression

# %%
regr = linear_model.LinearRegression()
regr.fit(X, Y) #performing the regression
# Out:
# LinearRegression()

# %% [markdown]
# ...and look at the coefficients...

# %%
theta0 = regr.intercept_
theta1 = regr.coef_
print('theta1 (slope): \n', theta0)
print('theta0 (intercept): \n', theta1)
# Out:
# theta1 (slope):
#  2.011258133146166
# theta0 (intercept):
#  [0.55412999]

# %% [markdown]
# ...and check how the model fits the data...

# %%
plt.scatter(X, Y) #print the sample points
plt.plot(X, theta0 + theta1*X) #print the regression line
plt.show()
